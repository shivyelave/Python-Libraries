# %% [markdown]
# '''
# <br><br>
#
# @Author: Shivraj Yelave <br>
# @Date: 12-08-24<br>
# @Last modified by: Shivraj Yelave<br>
# @Last modified time:<br>
# @Title: Matplotlib Scatter chart programs
# <br><br>
#
# '''

# %% [markdown]
# ## 1. Write a Python program to draw a scatter graph taking a random distribution in X and Y and plotted against each other.

# %%
import matplotlib.pyplot as plt
import numpy as np
def main():
    x = np.random.random(10)
    y = np.random.random(10)
    plt.scatter(x,y,marker = '*')
    plt.show()
if __name__ == '__main__':
    main()
# Out:
# [0.8483327  0.24569386 0.0787248  0.49954337 0.63584152 0.28177701
#  0.26342139 0.83290847 0.61114726 0.92776481] [0.32051984 0.56952564 0.65742361 0.72612911 0.65342789 0.61131441
#  0.806527   0.42458096 0.93627091 0.15214959]
